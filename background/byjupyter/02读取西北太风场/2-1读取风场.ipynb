# %%
import os
import pandas as pd
import numpy as np
import re
from datetime import datetime,timedelta
import numpy as np
import netCDF4 as nc
import pandas as pd
import numpy.ma as ma
import matplotlib as mpl
import matplotlib.pyplot as pltz
import xarray as xar
import rioxarray

# %%
file_path=r'../data/nwp_high_res_wind_2023080312.nc'

# %%
ds_xr=xar.open_dataset(file_path,decode_times=False)
ds_xr
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 451, lon: 451, time: 241)
# Coordinates:
#   * lat      (lat) float64 45.0 44.9 44.8 44.7 44.6 44.5 ... 0.4 0.3 0.2 0.1 0.0
#   * lon      (lon) float64 100.0 100.1 100.2 100.3 ... 144.7 144.8 144.9 145.0
#   * time     (time) int64 0 1 2 3 4 5 6 7 8 ... 233 234 235 236 237 238 239 240
# Data variables:
#     u10      (time, lat, lon) float32 ...
#     v10      (time, lat, lon) float32 ...
#     ws       (time, lat, lon) float32 ...
#     wd       (time, lat, lon) float32 ...

# %%
ds1=ds_xr.isel(time=0)

# %%
ds1
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 451, lon: 451)
# Coordinates:
#   * lat      (lat) float64 45.0 44.9 44.8 44.7 44.6 44.5 ... 0.4 0.3 0.2 0.1 0.0
#   * lon      (lon) float64 100.0 100.1 100.2 100.3 ... 144.7 144.8 144.9 145.0
#     time     int64 0
# Data variables:
#     u10      (lat, lon) float32 ...
#     v10      (lat, lon) float32 ...
#     ws       (lat, lon) float32 ...
#     wd       (lat, lon) float32 ...

# %%
ds_ws=ds1['ws']
ds_ws
# Out:
# <xarray.DataArray 'ws' (lat: 451, lon: 451)>
# array([[3.419273, 2.568418, 1.93134 , ..., 6.020409, 5.882899, 5.761148],
#        [1.881286, 1.805788, 2.015315, ..., 5.945004, 5.704952, 5.490525],
#        [2.64441 , 1.687938, 2.199998, ..., 5.600346, 5.591608, 5.599464],
#        ...,
#        [0.784458, 1.112753, 0.906576, ..., 3.92463 , 3.601149, 3.435938],
#        [0.616053, 0.634589, 0.467027, ..., 4.16131 , 3.839365, 3.869019],
#        [0.266945, 0.107127, 0.047506, ..., 4.333315, 4.308576, 4.377648]],
#       dtype=float32)
# Coordinates:
#   * lat      (lat) float64 45.0 44.9 44.8 44.7 44.6 44.5 ... 0.4 0.3 0.2 0.1 0.0
#   * lon      (lon) float64 100.0 100.1 100.2 100.3 ... 144.7 144.8 144.9 145.0
#     time     int64 0
# Attributes:
#     long_name:  Wind Speed
#     units:      m/s

# %%
output_file_fullpath=r'../data/nwp_high_res_wind_ws_2023080312.tif'
ds_ws=ds_ws.rio.set_spatial_dims('lon','lat')
ds_ws
# Out:
# <xarray.DataArray 'ws' (lat: 451, lon: 451)>
# array([[3.419273, 2.568418, 1.93134 , ..., 6.020409, 5.882899, 5.761148],
#        [1.881286, 1.805788, 2.015315, ..., 5.945004, 5.704952, 5.490525],
#        [2.64441 , 1.687938, 2.199998, ..., 5.600346, 5.591608, 5.599464],
#        ...,
#        [0.784458, 1.112753, 0.906576, ..., 3.92463 , 3.601149, 3.435938],
#        [0.616053, 0.634589, 0.467027, ..., 4.16131 , 3.839365, 3.869019],
#        [0.266945, 0.107127, 0.047506, ..., 4.333315, 4.308576, 4.377648]],
#       dtype=float32)
# Coordinates:
#   * lat      (lat) float64 45.0 44.9 44.8 44.7 44.6 44.5 ... 0.4 0.3 0.2 0.1 0.0
#   * lon      (lon) float64 100.0 100.1 100.2 100.3 ... 144.7 144.8 144.9 145.0
#     time     int64 0
# Attributes:
#     long_name:  Wind Speed
#     units:      m/s

# %%
# ERROR: InvalidDimensionOrder: Invalid dimension order.
# Expected order: ('lon', 'lat')You can use
# `DataArray.transpose('lon', 'lat')` to reorder your dimensions. Data variable: ws
ds_ws.rio.to_raster(output_file_fullpath)
