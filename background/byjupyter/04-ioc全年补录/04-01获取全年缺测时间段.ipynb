# %%
from typing import List

import pandas as pd
from datetime import timedelta
import io
import os
from pathlib import Path

# %% [markdown]
# 缺测汇总文件目录

# %%
read_static_path:Path = Path(r'/Volumes/DRCC_DATA/01DATA/03IOC/天文潮/2026/2025缺测统计/汇总')/'missing_ranges_result.csv'

# %%
df=pd.read_csv(str(read_static_path))

# %%
df.head()
# Out:
#   StationName            StartTime              EndTime
# 0       AMTSI  2025-01-01 00:00:00  2025-01-30 00:00:00
# 1       AMTSI  2025-01-30 00:00:00  2025-02-28 00:00:00
# 2       AMTSI  2025-02-28 00:00:00  2025-03-29 00:00:00
# 3       AMTSI  2025-03-29 00:00:00  2025-04-27 00:00:00
# 4       AMTSI  2025-04-27 00:00:00  2025-05-26 00:00:00

# %% [markdown]
# 共543个站位需要大部分补录

# %%
set(df['StationName'].to_list())
# Out:
# {'AMTSI',
#  'AN15',
#  'BANSI',
#  'BETSI',
#  'CETR',
#  'CIDJI',
#  'CT03',
#  'ENGSI',
#  'GESJI',
#  'GRJJI',
#  'IT45',
#  'IsHor',
#  'KMMSI',
#  'KUTBI',
#  'LAMSI',
#  'MRTM',
#  'MRTMI',
#  'Male2',
#  'PAYJI',
#  'PE09',
#  'PEISI',
#  'PL14',
#  'PO40',
#  'PT17',
#  'RA10',
#  'RC09',
#  'SA16',
#  'SB36',
#  'SC43',
#  'SIMSI',
#  'SRMPI',
#  'SUBSI',
#  'TA18',
#  'TBSSI',
#  'TEDSI',
#  'TLBJI',
#  'TR22',
#  'UAPO',
#  'VE19',
#  'aarh',
#  'abur',
#  'acaj',
#  'acnj2',
#  'agua',
#  'aigi',
#  'alak2',
#  'alex',
#  'alex2',
#  'alex3',
#  'alme2',
#  'alva2',
#  'amas',
#  'amor',
#  'anch',
#  'ancu2',
#  'ande',
#  'angu',
#  'anta',
#  'anti',
#  'anto',
#  'apfl',
#  'apla',
#  'aracS',
#  'arca',
#  'arca2',
#  'aren',
#  'aric',
#  'aric2',
#  'ascen',
#  'asto',
#  'atka',
#  'balc',
#  'balt',
#  'bara',
#  'barc2',
#  'batr1',
#  'bbst',
#  'bbst2',
#  'bmsa2',
#  'bodr',
#  'bois',
#  'bozy',
#  'bres2',
#  'brom',
#  'brpt',
#  'brur',
#  'bull',
# ...
