# %%
import os
import re

# %%
def extract_codes_from_directory(directory_path):
    """
    提取指定目录下所有文件名中第一个 '_' 之前的 code
    要求 code 必须是英文或英文+数字的组合
    """
    codes = set() # 使用 set 去重
    
    # 检查目录是否存在
    if not os.path.exists(directory_path):
        print(f"错误: 目录 '{directory_path}' 不存在！")
        return []

    # 编译正则表达式：仅匹配字母和数字组合 (英文或英文+数字)
    # ^[a-zA-Z0-9]+$ 表示从头到尾都必须是字母或数字
    pattern = re.compile(r'^[a-zA-Z0-9]+$')

    # 遍历目录下的所有文件
    for filename in os.listdir(directory_path):
        # 跳过隐藏文件 (如 .DS_Store) 或目录
        if filename.startswith('.') or os.path.isdir(os.path.join(directory_path, filename)):
            continue
            
        # 确保文件名中包含 '_'
        if '_' in filename:
            # 提取第一个 '_' 之前的部分
            code = filename.split('_')[0]
            
            # 校验提取出的 code 是否符合"英文或英文+数字"的要求
            if pattern.match(code):
                codes.add(code)
                
    # 转换为列表并排序，方便查看
    return sorted(list(codes))

# %%
# --- 请在这里修改为你的实际目录路径 ---
# 例如：你的数据存放在 "annual_data_2025" 文件夹下
target_dir = "/Volumes/DRCC_DATA/01DATA/03IOC/天文潮/2026/2026预测-全部" 

result_codes = extract_codes_from_directory(target_dir)

print(f"总共提取到 {len(result_codes)} 个独立的 code。")
print("-" * 40)

# 打印结果，也可以将结果写入到文本文件中
print(result_codes)

# 如果你想把提取出来的 code 数组直接复制到代码里，可以用下面的格式打印：
# print("[\n    '" + "',\n    '".join(result_codes) + "'\n]")
# Out:
# 总共提取到 480 个独立的 code。
# ----------------------------------------
# ['AZ42', 'CA02', 'CF06', 'CI20', 'GA37', 'LA23', 'PA07', 'PL14', 'PO40', 'PT17', 'RA10', 'SA16', 'TR22', 'UAPO', 'VE19', 'abas', 'abed', 'abur', 'acnj2', 'acor1', 'adak2', 'ajac', 'ajac2', 'alak2', 'alam', 'alge', 'alme', 'alva', 'alva2', 'amal', 'amal2', 'anch2', 'ancu', 'ancu2', 'ande', 'anto', 'anto2', 'apfl', 'arca', 'aren', 'aric', 'aric2', 'arre', 'arsu', 'asto', 'auct', 'audi', 'avon', 'ball', 'balt', 'bame', 'bame2', 'bang', 'bapj', 'bara', 'barn', 'bdto', 'bele', 'benc', 'benc2', 'beno', 'bgct', 'bgct2', 'bil3', 'blow', 'blueb', 'bmsa', 'bmsa2', 'bmso', 'boma', 'bon2', 'boul', 'bour', 'boye', 'boye2', 'bozy', 'bres', 'brom', 'bull', 'cala', 'cala2', 'cald', 'cald2', 'cbmd2', 'ceut', 'chala', 'char', 'chat', 'cher', 'chij', 'chit', 'chnr', 'chnr2', 'chrp', 'chrp2', 'chst', 'chtt', 'cmet', 'cmet3', 'cmnj', 'cmnj2', 'coli', 'coli2', 'conc', 'conc2', 'coqu', 'coqu2', 'cor2', 'cord2', 'corr', 'corr2', 'coru', 'cpit', 'crbc', 'cres', 'cres2', 'crnl2', 'crom', 'cstr', 'cstr2', 'cule', 'cwfl2', 'cwme', 'darw', 'dese', 'dial', 'diel', 'diel2', 'diep', 'diep2', 'dove', 'dunk', 'dunk2', 'dutc2', 'dzao', 'dzao2', 'east', 'east2', 'elak', 'elak2', 'elpo', 'esme', 'espe', 'fbfl', 'fbfl2', 'fer2', 'ferg', 'fish', 'fmfl', 'fpga2', 'fpnt2', 'ftfr', 'ftfr2', 'fue2', 'fuer2', 'futu', 'gale', 'gamb', 'gbit', 'gcsb', 'gibr3', 'gij2', 'gist', 'groo', 'gtdpr', 'gyer', 'hako', 'hana', 'harw', 'helg', 'herb', 'herb2', 'heys', 'hie2', 'hilo2', 'hink', 'hmda', 'holy2', 'honn', 'horn', 'huat2', 'huel', 'ilfa', 'immi', 'iqui', 'ishig', 'itea', 'jack', 'jers', 'john', 'juan', 'juan2', 'kahu', 'kahu2', 'kait', 'kapi', 'kara', 'kawa2', 'kerg2', 'kinl', 'kodi2', 'koli', 'koli2', 'kush', 'kusm', 'kwaj2', 'lajo', 'lalb', 'lali', 'lame', 'lamu', 'lapa', 'larp', 'larp2', 'lasp', 'laun', 'laza', 'laza2', 'lebu', 'lebu2', 'leco', 'lecy', 'lega', 'leha', 'leha2', 'leit', 'lero', 'lerw2', 'leso2', 'levu', 'lime', 'lime2', 'limon', 'lirf', 'live', 'lobos', 'lott', 'lowe', 'lpaz2', 'lpbc', 'luba', 'madry', 'magi', 'mal3', 'mala', 'malh', 'malo', 'mare', 'mari', 'mata', 'maya', 'meji', 'meji2', 'meli', 'mera', 'mhav', 'midx', 'mill', 'mimz', 'miqu', 'momb', 'mona2', 'mont', 'motr', 'mumb', 'naga', 'naha', 'napt', 'nawi', 'nbrt', 'ncpt', 'newl2', 'nhav', 'nhte', 'nkfa', 'npor', 'nshi', 'nspi', 'nspi2', 'ntue', 'ntue2', 'nuk1', 'nuku', 'nyal', 'ofun', 'omae', 'oste', 'otat', 'ouis2', 'paak', 'pagi2', 'pago', 'paita', 'palb', 'palm1', 'pape', 'pape2', 'papo', 'papo2', 'pata2', 'pbol', 'pcha', 'pcha2', 'pdas', 'pedn2', 'phbc', 'pich2', 'pisa', 'pisa2', 'pisco', 'pkem', 'plym', 'pmel', 'pmel2', 'pmon', 'pmon2', 'pmur', 'porl', 'porp', 'port', 'port2', 'pric', 'prus', 'psla2', 'pslu', 'pslu2', 'ptal', 'ptar', 'ptar2', 'ptbl', 'ptca', 'ptlu', 'ptmd2', 'ptmt', 'ptpl', 'ptsp', 'puer2', 'puert', 'puna', 'puyt', 'pwil2', 'qaqo', 'qtro', 'quar', 'quel', 'quel2', 'quepo', 'quir', 'quir2', 'rbct', 'reun', 'reun2', 'rorv', 'rosc', 'rosc2', 'rose', 'ross', 'rothe', 'sado', 'saig', 'sain', 'sali2', 'san2', 'sana', 'sand', 'sanf', 'sanf3', 'sanj2', 'sano2', 'scoa', 'scoa2', 'sdpt2', 'setp1', 'sev2', 'sewa2', 'shee', 'shek', 'sitk2', 'sjuan', 'slor', 'sole2', 'solo', 'spmi', 'sprg', 'stdpr', 'sthl2', 'stlu', 'stlu3', 'stlu4', 'stma', 'stma2', 'stmr', 'stor', 'stqy', 'stqy2', 'subi', 'sura', 'tala', 'talc', 'talc2', 'talt', 'talt2', 'tanp', 'tara', 'tari', 'tasu', 'taut', 'tboz', 'tbwc', 'tche', 'tcim', 'tdas', 'tdog', 'tdoj', 'tene', 'tfan', 'tfbc', 'tfug', 'thev', 'thou', 'thsi', 'thua', 'tjia', 'tjib', 'tkee', 'tlan', 'tlin', 'tlon', 'tlyu', 'tmai', 'tobe', 'toco2', 'toco3', 'tosa', 'tpen', 'trin', 'trst', 'tshi', 'tsic', 'tsua', 'tsyu', 'ttai', 'tubua', 'tudy', 'twai', 'twun', 'twus', 'txig', 'txil', 'tyon', 'tzha', 'upol', 'ushu', 'vair', 'vald2', 'valp', 'valp2', 'vard', 'vern', 'vhbc', 'vibc', 'vieq', 'vieq2', 'vig2', 'vil2', 'vish', 'viti', 'wall', 'weym', 'whbc', 'whit', 'wick', 'wlgt', 'wood2', 'work', 'wpwa', 'yaku', 'zanz', 'zihu', 'zihu2']
